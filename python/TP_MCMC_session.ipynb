# %% [markdown]
# Ouvrir ce notebook dans :
# <a href="https://colab.research.google.com/github/joanglaunes/algosto/blob/master/python/TP_MCMC.ipynb" target="_blank">Google Colab</a>
# ou
# <a href="https://rosenblatt.ens.math-info.univ-paris5.fr/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fjoanglaunes%2Falgosto&urlpath=tree%2Falgosto%2Fpython%2FTP_MCMC.ipynb&branch=master" target="_blank">Rosenblatt</a>

# %% [markdown]
# $\newcommand{\si}{\sigma}
# \newcommand{\al}{\alpha}
# \newcommand{\tta}{\theta}
# \newcommand{\Tta}{\Theta}
# \newcommand{\Si}{\Sigma}
# \newcommand{\ld}{\ldots}
# \newcommand{\cd}{\cdots}
# \newcommand{\cN}{\mathcal{N}}
# \newcommand{\R}{\mathbb{R}}
# \newcommand{\p}{\mathbb{P}}
# \newcommand{\f}{\frac}
# \newcommand{\ff}{\frac{1}}
# \newcommand{\ds}{\displaystyle}
# \newcommand{\bE}{\mathbf{E}}
# \newcommand{\E}{\mathbb{E}}
# \newcommand{\bF}{\mathbf{F}}
# \newcommand{\ii}{\mathrm{i}}
# \newcommand{\me}{\mathrm{e}}
# \newcommand{\hsi}{\hat{\sigma}}
# \newcommand{\hmu}{\hat{\mu}}
# \newcommand{\ste}{\, ;\, }
# \newcommand{\op}{\operatorname}
# \newcommand{\argmax}{\op{argmax}}
# \newcommand{\lfl}{\lfloor}
# \newcommand{\ri}{\right}
# \newcommand{\supp}{\operatorname{supp}}
# $
#
# # TP Introduction MCMC
#
# On commence par importer les librairies qui nous serons utiles dans le TP.

# %%
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
from time import time

# %%
#from TP_MCMC import *

# %% [markdown]
# ## Metropolis-Hasting versus rejet
#
# ### Rappel sur l'algorithme de rejet
# Soit $f$ la densité sous laquelle on cherche à  simuler, appelée *densité cible*. On considère une autre densité $g$ (par rapport à  $\mu$), appelée *densité de proposition*, telle que:
# - il est aisé de simuler suivant $g$,
# - il existe une constante $M$ telle que $f(x)\leq M g(x)$ pour tout $x$ (ce qui implique que $M\ge 1$ et $\supp (f) \subset \supp(g)$).
#
# On peut alors générer   un échantillon suivant l'algorithme suivant:
#
# **Algorithme de rejet de simulation de $X$ de densité $f$**
# 1. Générer $X$ suivant la densité $g$.
# 2. Générer $U$ suivant une loi $Unif([0,M])$
# 3. Accepter  la valeur $X$ si $U\le \frac{f(X)}{ g(X)}$, sinon, recommencer.
#
# ### Algorithme de Metropolis Hasting
#
# On a par ailleurs vu en cours l'algorithme de Metropolis-Hasting.
# Soit   $f$ une densité de probabilité sur $\R^d$. Posons $\supp_{>}(f):= {\{x\ste f(x)> 0\}}$.
#
# **Algorithme de Metropolis-Hastings de simulation de $X$ de densité $\approx f$**
#
# 1. Choisir un noyau de transition $Q$ irréductible apériodique sur  $\supp_{>}(f)$.
# 2. Choisir $x\in \supp_{>}(f)$.
# 3. Répéter un grand nombre de fois :
#     + tirer, indépendamment, $Y\sim Q(x,\cdot)$ et $U\sim Unif([0,1])$,
#     + remplacer $x$ par $Y$ si $U <\f{f(Y)Q(x,Y)}{f(x)Q(Y,x)}$ et le laisser invariant sinon.$$
# 4. Retourner $X:=x$.
#
# ### Exercice
# Le but ici est de générer des échantillons selon la loi sur $\R$ de densité :
# $$\pi_\al(x) =\ff{\sqrt{2\pi}} \me^{-x^2/2}(1 + \sin(\al x))\,$$
# où $\al>0$ (on pourra prendre $\al=2$).

# %% [markdown]
# **Question 1** : Tracer la densité $\pi_\al$ pour plusieurs valeurs de $\al$.

# %%
def f(x,alpha):
    return sps.norm.pdf(x)*(1+np.sin(alpha*x))

plt.figure()
x=np.linspace(-5,5,int(1e4))
for alpha in [1,2,5]:
    y=f(x,alpha)
    plt.plot(x,y,label='alpha = %s'%alpha)
plt.title("Density")
plt.legend()
plt.show()

# %% [markdown]
# **Question 2** :   Simuler un échantillon de taille $n=1000$ de variables i.i.d. de   loi de densité $\pi_\al$ via  la méthode de Metropolis Hasting avec une loi de proposition $Q(x,.)=N(x,\si^2)$ (pour $\si=1$ par exemple). On mesurera le temps T que prend la simulation avec la commande `time()` de la librairie `time`.

# %%
Nsteps = 20 # nombre d'itérations de l'algorithme
# en pratique il faudrait plus d'échantillons pour bien converger, mais cela prendrait trop de temps
# on prend donc Nsteps=20 ici et on initialise HM avec une loi initiale gaussienne ce qui permet de vite converger car elle ressemble à f
sigma = 1
alpha = 2

def HM(Nsteps,sigma,alpha):
    # doit renvoyer X_n avec n=Nsteps, où X_k sont simulés suivant l'algo Metropolis-Hastings 
    Q = lambda x,y : (1/np.sqrt(2*np.pi)/sigma) * np.exp(-(x-y)**2/sigma**2)
    x = np.random.randn()*sigma
    for i in range(Nsteps):
        Y = np.random.randn()*sigma+x
        U = np.random.rand()
        if U<(f(Y,alpha)*Q(x,Y))/(f(x,alpha)*Q(Y,x)):
            x = Y
    return x

# on peut remarquer que Q est symétrique, donc on peut simplifier par Q (c'est l'lgorithme de Metropolis):

def HM(Nsteps,sigma,alpha):
    # doit renvoyer X_n avec n=Nsteps, où X_k sont simulés suivant l'algo Metropolis
    x = np.random.randn()*sigma
    for i in range(Nsteps):
        Y = np.random.randn()*sigma+x
        U = np.random.rand()
        if U<f(Y,alpha)/f(x,alpha):
            x = Y
    return x


# On echantillonne 1000 fois avec la fonction HM (à écrire)
n=int(1e3)
Ech=[]
t = time()
for i in range(n):
    Ech.append(HM(Nsteps,sigma,alpha))
tempsHM=time()-t

# Estimation de l'espérance de la loi,
mHM=np.mean(Ech)
eHM=1.96*np.std(Ech)/np.sqrt(n)
print("\nEstimation de la moyenne : "+str(mHM))
print("\nErreur sur l'estimation de la moyenne : "+str(eHM))
print("\nTemps nécessaire pour tirer 1000 echantillons: "+str(tempsHM))
# Out:
# Estimation de la moyenne : 0.2632056851637268
#
# Erreur sur l'estimation de la moyenne : 0.061269559099899104
#
# Temps nécessaire pour tirer 1000 echantillons: 6.954588413238525

# %%
# affichage de l'histogramme des echantillons

alpha = 2
plt.figure()
x=np.linspace(-5,5,int(1e4))
y=f(x,alpha)
plt.plot(x,y,"r")
plt.hist(Ech, bins=100,density=1, histtype="step")
plt.title("HM sample")
plt.show()

# %%
# On écrit ici une version parallélisée pour accélérer le code
# Avec les mêmes paramètres (Nsteps=20 et n=1000), le code suivant
# permet de passer de 8 secondes à 0.02 secondes environ !

# Du coup on peut se permettre de prendre des valeurs plus grandes:
# Nsteps = 100 pour avoir assez d'itérations de l'algorithme
# n=10000 pour avoir un plus grand échantillon

Nsteps = 100
n=int(1e4)

# version parallélisée:
def HM_batch(n,Nsteps,sigma,alpha):
    # doit renvoyer X_n avec n=Nsteps, où X_k sont simulés suivant l'algo Metropolis
    x = np.random.randn(n)*sigma
    for i in range(Nsteps):
        Y = np.random.randn(n)*sigma+x
        U = np.random.rand(n)
        test = U<f(Y,alpha)/f(x,alpha)
        x[test] = Y[test]
    return x

t = time()
Ech = HM_batch(n,Nsteps,sigma,alpha)
tempsHM=time()-t

# Estimation de l'espérance de la loi,
mHM=np.mean(Ech)
eHM=1.96*np.std(Ech)/np.sqrt(n)
print("\nEstimation de la moyenne : "+str(mHM))
print("\nErreur sur l'estimation de la moyenne : "+str(eHM))
print(f"\nTemps nécessaire pour tirer {n} echantillons: "+str(tempsHM))
# Out:
# Estimation de la moyenne : 0.27253851148210656
#
# Erreur sur l'estimation de la moyenne : 0.018666041078839516
#
# Temps nécessaire pour tirer 10000 echantillons: 0.2979891300201416

# %%
# affichage de l'histogramme des echantillons

alpha = 2
plt.figure()
x=np.linspace(-5,5,int(1e4))
y=f(x,alpha)
plt.plot(x,y,"r")
plt.hist(Ech, bins=100,density=1, histtype="step")
plt.title("HM sample")
plt.show()

# %% [markdown]
# **Question 3** : Simuler ensuite, en dédiant à la tâche le même temps T que pour la simulation précédente,  un échantillon par méthode de rejet (on notera que $\pi_\alpha(x)\le 2g(x)$ pour $g$ la densité de $N(0,1)$).
#
# **Question4** : Comparer les histogrammes et afficher le rapport entre les tailles des deux échantillons ainsi simulés. Quelle méthode permet de simuler le plus grand échantillon pendant le temps T ?
#
# **Question 5** :   Calculer ensuite la valeur théorique de l'espérance ainsi que sa valeur empirique calculée grâce aux deux méthodes.

# %%
# Echantillonnage pendant le même temps que pour HM
# Remarque : pour le rejet, on pourra remarquer que le quotient à calculer se simplifie, ce qui permet de faire un calcul très rapide
Ech=[]
t = time()
while time()-t<tempsHM:
    Ech.append(Rejet(alpha))

m=len(Ech)

print("Rapport nombre d'échantillons Rejet / HM pour le même temps de calcul : "+str(m/float(n)))
# Out:
# Rapport nombre d'échantillons Rejet / HM pour le même temps de calcul : 1184.865

# %%
# Affichage de l'histogramme
plt.figure()
x=np.linspace(-5,5,int(1e4))
y=f(x,alpha)
plt.plot(x,y,"r")
plt.hist(Ech, bins=100,density=1, histtype="step")
plt.title("Reject sample")
plt.show()

# estimation de la moyenne
mR=np.mean(Ech)
eR=1.96*np.std(Ech)/np.sqrt(m)
mT = alpha*np.exp(-.5*alpha**2)
print("\nEstimation la moyenne :")
print("Valeur reelle : %.3e" % mT)
print("Methode rejet : %.3e +/-%.3e" % (mR,eR))
print("Methode HM : %.3e +/-%.3e" % (mHM,eHM))
# Out:
# Estimation la moyenne :
# Valeur reelle : 2.707e-01
# Methode rejet : 2.717e-01 +/-1.733e-03
# Methode HM : 1.748e-01 +/-6.461e-02
